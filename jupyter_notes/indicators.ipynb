# %%
import sys
sys.path.append('../')
from plotting import CandlePlot
import pandas as pd

# %%
from technicals.indicators import BollingerBands, ATR, KelterChannels, RSI

# %%
df = pd.read_pickle('../data/AUD_CAD_H1.pkl')

# %%
df_an = df.copy()

# %%
df_an = RSI(df_an)

# %%
dfp = df_an.iloc[-100:]
cp = CandlePlot(dfp, candles=True)
cp.show_plot(line_traces=[], sec_traces=['RSI_14'])
