# %%
import sys
sys.path.append('../')
from plotting import CandlePlot
import pandas as pd

# %%
from technicals.indicators import BollingerBands, ATR, KelterChannels, RSI, MACD

# %%
df = pd.read_pickle('../data/AUD_CAD_H1.pkl')

# %%
df_an = df.copy()

# %%
df_an = MACD(df_an)

# %%
dfp = df_an.iloc[-300:]
cp = CandlePlot(dfp, candles=True)
cp.show_plot(line_traces=[])

# %%
import plotly.graph_objects as go

# %%
cp = CandlePlot(dfp, candles=False)
cp.fig.add_trace(go.Bar(x=cp.df_plot.sTime, y=cp.df_plot.HIST, name='HIST'))
cp.show_plot(line_traces=['SIGNAL', 'MACD'], sec_traces=[])
