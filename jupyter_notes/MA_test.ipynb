# %%
import sys
sys.path.append("../")
import pandas as pd
import plotly.graph_objects as go
import datetime as dt
from plotting import CandlePlot

# %%
from infrastructure.instrument_collection import instrumentCollection as ic

# %%
pair = 'GBP_JPY'
granularity = "H4"
df = pd.read_pickle(f"../data/{pair}_{granularity}.pkl")
MA_LIST = [10, 20, 50, 100, 200]

# %%
df_ma = df[['time', 'mid_o', 'mid_h', 'mid_l', 'mid_c']].copy()

# %%
df_ma.head()
# Out:
#                        time    mid_o    mid_h    mid_l    mid_c
# 0 2021-01-20 02:00:00+00:00  141.635  141.728  141.580  141.661
# 1 2021-01-20 06:00:00+00:00  141.663  142.144  141.652  142.104
# 2 2021-01-20 10:00:00+00:00  142.108  142.336  141.813  141.850
# 3 2021-01-20 14:00:00+00:00  141.852  141.919  141.082  141.338
# 4 2021-01-20 18:00:00+00:00  141.336  141.450  141.244  141.388

# %%
for ma in MA_LIST:
    df_ma[f'MA_{ma}'] = df_ma.mid_c.rolling(window=ma).mean()
df_ma.dropna(inplace=True)
df_ma.reset_index(inplace=True, drop=True)

# %%
df_plot = df_ma.iloc[:500]

# %%
cp = CandlePlot(df_plot)

# %%
traces = [f'MA_{x}' for x in MA_LIST]

# %%
# cp.fig.add_trace(go.Scatter(
#     x=cp.df_plot.sTime,
#     y=cp.df_plot.MA_10,
#     line=dict(width=2),
#     line_shape='spline',
#     name='MA_10'
# ))
cp.show_plot(line_traces=traces)

# %%
MA_S = "MA_50"
MA_L = "MA_200"
BUY = 1
SELL = -1
NONE = 0

# %%
df_an = df_ma[['time', 'mid_o', 'mid_h', 'mid_l', 'mid_c', MA_S, MA_L]].copy()

# %%
df_an.head(30)
# Out:
#                         time    mid_o    mid_h    mid_l    mid_c      MA_50  \
# 0  2021-03-08 06:00:00+00:00  149.898  150.202  149.688  150.161  149.31008
# 1  2021-03-08 10:00:00+00:00  150.163  150.588  150.021  150.537  149.33128
# 2  2021-03-08 14:00:00+00:00  150.534  150.686  150.270  150.678  149.34880
# 3  2021-03-08 18:00:00+00:00  150.676  150.701  150.476  150.566  149.37144
# 4  2021-03-08 22:00:00+00:00  150.539  150.850  150.434  150.774  149.40062
# 5  2021-03-09 02:00:00+00:00  150.772  151.233  150.770  151.100  149.42906
# 6  2021-03-09 06:00:00+00:00  151.102  151.197  150.814  151.014  149.45090
# 7  2021-03-09 10:00:00+00:00  151.016  151.265  150.784  151.201  149.47566
# 8  2021-03-09 14:00:00+00:00  151.204  151.283  150.704  150.744  149.48410
# 9  2021-03-09 18:00:00+00:00  150.746  150.819  150.640  150.684  149.49518
# 10 2021-03-09 22:00:00+00:00  150.692  150.944  150.648  150.766  149.51968
# 11 2021-03-10 02:00:00+00:00  150.760  150.981  150.746  150.898  149.56076
# 12 2021-03-10 06:00:00+00:00  150.895  151.192  150.730  151.156  149.61248
# 13 2021-03-10 10:00:00+00:00  151.154  151.184  150.644  150.846  149.66656
# 14 2021-03-10 14:00:00+00:00  150.848  151.048  150.734  150.884  149.71472
# 15 2021-03-10 18:00:00+00:00  150.886  151.078  150.865  151.057  149.76832
# 16 2021-03-10 22:00:00+00:00  150.981  151.172  150.885  151.112  149.81612
# 17 2021-03-11 02:00:00+00:00  151.114  151.572  151.114  151.517  149.87812
# 18 2021-03-11 06:00:00+00:00  151.520  151.690  151.152  151.319  149.92194
# 19 2021-03-11 10:00:00+00:00  151.316  151.671  151.274  151.625  149.97520
# 20 2021-03-11 14:00:00+00:00  151.622  151.672  151.478  151.617  150.03064
# 21 2021-03-11 18:00:00+00:00  151.614  151.838  151.512  151.832  150.09440
# 22 2021-03-11 22:00:00+00:00  151.822  152.152  151.746  152.058  150.16292
# 23 2021-03-12 02:00:00+00:00  152.060  152.086  151.908  151.980  150.22896
# 24 2021-03-12 06:00:00+00:00  151.978  152.238  151.760  151.801  150.29202
# 25 2021-03-12 10:00:00+00:00  151.804  151.935  151.252  151.468  150.35546
# 26 2021-03-12 14:00:00+00:00  151.466  151.827  151.233  151.802  150.42702
# 27 2021-03-12 18:00:00+00:00  151.805  151.912  151.725  151.776  150.48774
# 28 2021-03-14 21:00:00+00:00  151.854  152.026  151.711  151.942  150.54470
# 29 2021-03-15 01:00:00+00:00  151.940  152.055  151.892  152.033  150.60734
#
#         MA_200
# 0   145.723970
# 1   145.768350
# 2   145.811220
# 3   145.854800
# 4   145.901980
# 5   145.950540
# 6   145.997650
# 7   146.045870
# 8   146.089405
# 9   146.132715
# 10  146.176675
# 11  146.220490
# 12  146.265850
# 13  146.310155
# 14  146.356185
# 15  146.402955
# 16  146.448455
# 17  146.496070
# 18  146.542265
# 19  146.589150
# 20  146.637575
# 21  146.686785
# 22  146.737695
# 23  146.788165
# 24  146.838090
# 25  146.887290
# 26  146.937480
# 27  146.985870
# 28  147.033740
# 29  147.082305

# %%
df_an["DELTA"] = df_an.MA_50 - df_an.MA_200
df_an["DELTA_PREV"] = df_an.DELTA.shift(1)

# %%
def is_trade(row):
    if row.DELTA >= 0 and row.DELTA_PREV < 0:
        return BUY
    elif row.DELTA < 0 and row.DELTA_PREV >= 0:
        return SELL
    return NONE

# %%
df_an["TRADE"] = df_an.apply(is_trade, axis=1)

# %%
df_trades = df_an[df_an.TRADE != NONE].copy()

# %%
df_trades.head()
# Out:
#                          time    mid_o    mid_h    mid_l    mid_c      MA_50  \
# 170 2021-04-15 13:00:00+00:00  149.988  149.994  149.690  149.856  150.82828
# 250 2021-05-04 21:00:00+00:00  151.845  152.005  151.760  151.959  150.96454
# 454 2021-06-21 21:00:00+00:00  153.628  153.776  153.306  153.411  154.30770
# 664 2021-08-09 21:00:00+00:00  152.768  152.905  152.712  152.815  152.50896
# 706 2021-08-18 21:00:00+00:00  150.986  151.139  150.946  151.051  152.14970
#
#          MA_200     DELTA  DELTA_PREV  TRADE
# 170  150.902175 -0.073895    0.000280     -1
# 250  150.949005  0.015535   -0.027730      1
# 454  154.323890 -0.016190    0.017955     -1
# 664  152.508625  0.000335   -0.010650      1
# 706  152.150745 -0.001045    0.023490     -1

# %%
cp = CandlePlot(df_an.iloc[15:55])
cp.show_plot(line_traces=[MA_S, MA_L])

# %%
ic.load_instruments("../data")

# %%
ic.instruments_dict[pair]
# Out:
# {'name': 'GBP_JPY', 'ins_type': 'CURRENCY', 'displayName': 'GBP/JPY', 'pipLocation': 0.01, 'tradeUnitsPrecision': 0, 'marginRate': 0.05}

# %%
ins_data = ic.instruments_dict[pair]

# %%
df_trades.shape
# Out:
# (32, 10)

# %%
df_trades['DIFF'] = df_trades.mid_c.diff().shift(-1)
df_trades.fillna(0, inplace=True)

# %%
df_trades['GAIN'] = df_trades['DIFF'] / ins_data.pipLocation
df_trades['GAIN'] = df_trades['GAIN'] * df_trades['TRADE']

# %%
df_trades.GAIN.sum()
# Out:
# -6604.900000000009

# %%
df_trades['GAIN_C'] = df_trades['GAIN'].cumsum()

# %%
cp = CandlePlot(df_trades, candles=False)
cp.show_plot(line_traces=['GAIN_C'])
