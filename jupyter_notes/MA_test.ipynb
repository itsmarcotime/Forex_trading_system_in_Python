# %%
import pandas as pd
import plotly.graph_objects as go
import datetime as dt
from plotting import CandlePlot

# %%
pair = 'USD_JPY'
granularity = "H4"
df = pd.read_pickle(f"../data/{pair}_{granularity}.pkl")

# %%
df.columns
# Out:
# Index(['time', 'volume', 'mid_o', 'mid_h', 'mid_l', 'mid_c', 'bid_o', 'bid_h',
#        'bid_l', 'bid_c', 'ask_o', 'ask_h', 'ask_l', 'ask_c'],
#       dtype='object')

# %%
df_ma = df[['time', 'mid_o', 'mid_h', 'mid_l', 'mid_c']].copy()

# %%
df_ma.head()
# Out:
#                        time    mid_o    mid_h    mid_l    mid_c
# 0 2021-01-20 02:00:00+00:00  103.809  103.810  103.731  103.746
# 1 2021-01-20 06:00:00+00:00  103.748  103.839  103.716  103.793
# 2 2021-01-20 10:00:00+00:00  103.795  103.845  103.736  103.746
# 3 2021-01-20 14:00:00+00:00  103.746  103.788  103.448  103.602
# 4 2021-01-20 18:00:00+00:00  103.604  103.639  103.512  103.542

# %%
df_ma['MA_10'] = df_ma.mid_c.rolling(window=10).mean()
df_ma.dropna(inplace=True)
df_ma.reset_index(inplace=True, drop=True)

# %%
df_plot = df_ma.iloc[:100]

# %%
cp = CandlePlot(df_plot)

# %%
# cp.fig.add_trace(go.Scatter(
#     x=cp.df_plot.sTime,
#     y=cp.df_plot.MA_10,
#     line=dict(width=2),
#     line_shape='spline',
#     name='MA_10'
# ))
cp.show_plot(line_traces=['MA_10'])
