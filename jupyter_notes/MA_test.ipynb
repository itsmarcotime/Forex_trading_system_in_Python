# %%
import pandas as pd
import plotly.graph_objects as go
import datetime as dt
from plotting import CandlePlot

# %%
pair = 'USD_JPY'
granularity = "H4"
df = pd.read_pickle(f"../data/{pair}_{granularity}.pkl")
MA_LIST = [10, 20, 50, 100, 200]

# %%
df.columns
# Out:
# Index(['time', 'volume', 'mid_o', 'mid_h', 'mid_l', 'mid_c', 'bid_o', 'bid_h',
#        'bid_l', 'bid_c', 'ask_o', 'ask_h', 'ask_l', 'ask_c'],
#       dtype='object')

# %%
df_ma = df[['time', 'mid_o', 'mid_h', 'mid_l', 'mid_c']].copy()

# %%
df_ma.head()
# Out:
#                        time    mid_o    mid_h    mid_l    mid_c     MA_10  \
# 0 2021-03-08 06:00:00+00:00  108.350  108.608  108.350  108.566  108.2822
# 1 2021-03-08 10:00:00+00:00  108.565  108.739  108.476  108.692  108.3532
# 2 2021-03-08 14:00:00+00:00  108.691  108.944  108.638  108.884  108.4548
# 3 2021-03-08 18:00:00+00:00  108.882  108.936  108.814  108.899  108.5338
# 4 2021-03-08 22:00:00+00:00  108.884  109.204  108.866  109.198  108.6082
#
#        MA_20      MA_50     MA_100      MA_200
# 0  107.70680  106.92360  106.17961  105.335275
# 1  107.79795  106.98676  106.21906  105.360005
# 2  107.89755  107.04894  106.25979  105.385460
# 3  107.99810  107.10692  106.30006  105.411225
# 4  108.11020  107.17314  106.34163  105.439205

# %%
for ma in MA_LIST:
    df_ma[f'MA_{ma}'] = df_ma.mid_c.rolling(window=ma).mean()
df_ma.dropna(inplace=True)
df_ma.reset_index(inplace=True, drop=True)

# %%
df_plot = df_ma.iloc[:500]

# %%
cp = CandlePlot(df_plot)

# %%
traces = [f'MA_{x}' for x in MA_LIST]

# %%
# cp.fig.add_trace(go.Scatter(
#     x=cp.df_plot.sTime,
#     y=cp.df_plot.MA_10,
#     line=dict(width=2),
#     line_shape='spline',
#     name='MA_10'
# ))
cp.show_plot(line_traces=traces)

# %%
MA_S = "MA_10"
MA_L = "MA_20"
BUY = 1
SELL = -1
NONE = 0

# %%
df_an = df_ma[['time', 'mid_o', 'mid_h', 'mid_l', 'mid_c', MA_S, MA_L]].copy()

# %%
df_an.head()
# Out:
#                        time    mid_o    mid_h    mid_l    mid_c     MA_10  \
# 0 2021-03-08 06:00:00+00:00  108.350  108.608  108.350  108.566  108.2822
# 1 2021-03-08 10:00:00+00:00  108.565  108.739  108.476  108.692  108.3532
# 2 2021-03-08 14:00:00+00:00  108.691  108.944  108.638  108.884  108.4548
# 3 2021-03-08 18:00:00+00:00  108.882  108.936  108.814  108.899  108.5338
# 4 2021-03-08 22:00:00+00:00  108.884  109.204  108.866  109.198  108.6082
#
#        MA_20    DELTA  DELTA_PREV
# 0  107.70680  0.57540         NaN
# 1  107.79795  0.55525     0.57540
# 2  107.89755  0.55725     0.55525
# 3  107.99810  0.53570     0.55725
# 4  108.11020  0.49800     0.53570

# %%
df_an["DELTA"] = df_an.MA_10 - df_an.MA_20
df_an["DELTA_PREV"] = df_an.DELTA.shift(1)
